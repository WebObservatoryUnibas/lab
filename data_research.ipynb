# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pymysql

# %matplotlib inline

# %%
hdf = pd.read_hdf('catchacar.ch_allcardata.h5')

# %%
hdf[0:3]
# Out:
#     KID  IsBookable  EnergyLevel  IsServiceReservation  ID  EstimatedDistance  \
# 0  2787           1           99                     0   1                113
# 1  2788           1           97                     0   2                111
# 2  2789           1           68                     0   3                 78
#
#    GeoFenceIDs  IsCharging     GeoX     GeoY           Name CategoryName  \
# 0            0           0  47.5364  7.56936  Catch-Car 001       VW up!
# 1            0           0  47.5333  7.56841  Catch-Car 002       VW up!
# 2            0           0  47.5511  7.53156  Catch-Car 003       VW up!
#
#    IsFree  MinimumEnergyLevel                Time
# 0       1                  15 2016-05-19 00:00:04
# 1       1                  15 2016-05-19 00:00:04
# 2       1                  15 2016-05-19 00:00:04

# %%
tot=len(hdf)
tot
# Out:
# 4861025

# %%
#Select Car5
car5 = hdf.loc[hdf['Name'] == 'Catch-Car 005']
car5[0:3]
# Out:
#       KID  IsBookable  EnergyLevel  IsServiceReservation  ID  \
# 4    2791           1           99                     0   5
# 120  2907           1           99                     0   5
# 235  3022           1           99                     0   5
#
#      EstimatedDistance  GeoFenceIDs  IsCharging     GeoX     GeoY  \
# 4                  113            0           0  47.5564  7.56108
# 120                113            0           0  47.5564  7.56108
# 235                113            0           0  47.5564  7.56108
#
#               Name CategoryName  IsFree  MinimumEnergyLevel  \
# 4    Catch-Car 005       VW up!       1                  15
# 120  Catch-Car 005       VW up!       1                  15
# 235  Catch-Car 005       VW up!       1                  15
#
#                    Time
# 4   2016-05-19 00:00:04
# 120 2016-05-19 00:15:04
# 235 2016-05-19 00:30:04

# %%
l=[]
for i in range(len(car5)-1):
    b=car5.iloc[i]["Time"]
    c=car5.iloc[i+1]["Time"]
    d=c-b
    print(d)
# Out:
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:01
# 0 days 00:14:59
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:01
# 0 days 00:14:59
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:01
# 0 days 00:14:59
# 0 days 00:15:00
# 0 days 00:15:01
# 0 days 00:14:59
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:01
# 0 days 00:14:59
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:00
# 0 days 00:15:01
# 0 days 00:15:00
# 0 days 00:14:59
# 0 days 00:15:00
# ...

# %%
car5.iloc[2]["Time"]
# Out:
# Timestamp('2016-05-19 00:30:04')

# %%
for i in range(9):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
